# %%
import xarray as xr

# %%
xr.open_dataset('C:/Users/sa07kb/OneDrive - SAMS/data/data_RT_mooring/Rockall-Trough-Transport-Time-Series-2020.nc')
# Out:
# <xarray.Dataset>
# Dimensions:    (TIME: 4545)
# Coordinates:
#   * TIME       (TIME) datetime64[ns] 2014-07-21T12:00:00 ... 2020-10-09T12:00:00
# Data variables: (12/24)
#     Q_WW       (TIME) float32 ...
#     Q_MB       (TIME) float32 ...
#     Q_EW       (TIME) float32 ...
#     Q_tot      (TIME) float32 ...
#     Q_WW_lp    (TIME) float32 ...
#     Q_MB_lp    (TIME) float32 ...
#     ...         ...
#     Qf_EW      (TIME) float32 ...
#     Qf_tot     (TIME) float32 ...
#     Qf_WW_lp   (TIME) float32 ...
#     Qf_MB_lp   (TIME) float32 ...
#     Qf_EW_lp   (TIME) float32 ...
#     Qf_tot_lp  (TIME) float32 ...
# Attributes: (12/19)
#     title:                     CLASS Rockall Trough transport data 07/2014-10...
#     institution:               Scottish Association for Marine Science, Scott...
#     history:                   Delayed time processed quality controlled
#     id:                        Rockall-Trough-Transport-Time-Series-2020
# ...
